# %%
from pathlib import Path
from genetic_algorithm import genetic_algorithm
from genetic_algorithm.selection import TournamentSelection
from mwcnf_parser import parse_mwcnf
from solver import MwcnfGenerator
from solver.fitness import satisfied_clause_count, weights
from solver.mwcnf_individual import MwcnfIndividual

from io import StringIO
import matplotlib.pyplot as plt

# %%
from dataclasses import dataclass
from math import ceil, floor


actual_max_weights = {
    "wruf36-157-1.mwcnf": 9151,
    "wruf36-157-2.mwcnf": 5348,
    "wruf36-157-3.mwcnf": 16,
    "wruf36-157-4.mwcnf": 2074,
    "wruf36-157-5.mwcnf": 13604,
    "wruf36-157-6.mwcnf": 5895,
    "wruf36-157-7.mwcnf": 3154,
    "wruf36-157-8.mwcnf": 2088,
    "wruf36-157-9.mwcnf": 3420,
    "wruf36-157-10.mwcnf": 9865,
    "wuf50-01.mwcnf": 4190,
    "wuf50-02.mwcnf": 1469,
    "wuf50-03.mwcnf": 5305,
    "wuf50-04.mwcnf": 1488,
    "wuf50-05.mwcnf": 11315,
    "wuf50-06.mwcnf": 1012,
    "wuf50-07.mwcnf": 9570,
    "wuf50-08.mwcnf": 555,
    "wuf50-09.mwcnf": 1612,
    "wuf50-010.mwcnf": 3031,
    "wuf75-01.mwcnf": 6293,
    "wuf75-02.mwcnf": 6003,
    "wuf75-03.mwcnf": 297,
    "wuf75-04.mwcnf": 1019,
    "wuf75-05.mwcnf": 1950,
    "wuf75-06.mwcnf": 7470,
    "wuf75-07.mwcnf": 5891,
    "wuf75-08.mwcnf": 2747,
    "wuf75-09.mwcnf": 9285,
    "wuf75-010.mwcnf": 6976,
}


@dataclass
class Result:
    formula_name: str
    run_no: int
    clause_cnt: int
    sat_clause_cnt: int
    weight: int
    last_improvement: int
    pop_size: int
    max_weight: int

    def solved(self):
        return self.clause_cnt == self.sat_clause_cnt

    def get_int(self):
        return self.solved() * self.weight / self.max_weight

    def get_penalized_last_improvement(self):
        return (10 - (self.solved() * 9)) * self.last_improvement

stats = {}
with open("out/stats.csv", "rt") as stats_f:
    for line in stats_f.readlines():
        formula_name, run_no, clause_cnt, sat_clause_cnt, weight, last_improvement, pop_size = line.split(sep=",")

        dict_key = f"{clause_cnt}-{int(pop_size)}"
        stats.setdefault(dict_key, []).append(Result(formula_name,
                                                     int(run_no),
                                                     int(clause_cnt),
                                                     int(sat_clause_cnt),
                                                     int(weight),
                                                     int(last_improvement),
                                                     int(pop_size),
                                                     actual_max_weights.get(formula_name, 1),
                                                     ))

stats
# Out:
# {'218-600': [Result(formula_name='wuf50-01.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-01.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=12282, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=216, weight=21848, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=16836, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-01.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=4190, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=21845, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=21845, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=24790, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=17434, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=23319, last_improvement=0, pop_size=600, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=16515, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=15556, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-03.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-02.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=17796, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-03.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-02.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=600, max_weight=1469),
#   Result(formula_name='wuf50-03.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=5232, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=600, max_weight=5305),
#   Result(formula_name='wuf50-04.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=3620, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=11085, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=11085, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=12686, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=11086, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=8549, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-05.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=11315, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-04.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=12686, last_improvement=0, pop_size=600, max_weight=1488),
#   Result(formula_name='wuf50-05.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=10634, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-06.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=15780, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-05.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=600, max_weight=11315),
#   Result(formula_name='wuf50-06.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-06.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=4810, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-06.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=14305, last_improvement=0, pop_size=600, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=5423, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=8845, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=6366, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=12102, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=12102, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=11154, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-07.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=4659, last_improvement=0, pop_size=600, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=11156, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=15929, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=215, weight=15397, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-09.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=1612, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-08.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=600, max_weight=555),
#   Result(formula_name='wuf50-09.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=2728, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=5517, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=3094, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=5001, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=5001, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=4677, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=1612, last_improvement=0, pop_size=600, max_weight=1612),
#   Result(formula_name='wuf50-010.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=7809, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=8234, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=7583, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=2928, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=3770, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=2127, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=2963, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=5363, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=4164, last_improvement=0, pop_size=600, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=6200, last_improvement=0, pop_size=600, max_weight=3031)],
#  '218-450': [Result(formula_name='wuf50-01.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=24790, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=215, weight=24547, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=11302, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=215, weight=26264, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-01.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=450, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=16517, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=16836, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16836, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=17796, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=450, max_weight=1469),
#   Result(formula_name='wuf50-03.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=4851, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=5281, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=8849, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=450, max_weight=5305),
#   Result(formula_name='wuf50-04.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=11217, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=7884, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=7884, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=216, weight=12682, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=11084, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=11752, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-05.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-04.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=12682, last_improvement=0, pop_size=450, max_weight=1488),
#   Result(formula_name='wuf50-05.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=10634, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=12204, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=8320, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=10486, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=450, max_weight=11315),
#   Result(formula_name='wuf50-06.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=14305, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=15780, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=14305, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=14305, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=450, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=8044, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=11669, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=8569, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=7002, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=15929, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-07.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=5583, last_improvement=0, pop_size=450, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=215, weight=16990, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=215, weight=15402, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=11162, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-09.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=5882, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-08.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=216, weight=14869, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=16985, last_improvement=0, pop_size=450, max_weight=555),
#   Result(formula_name='wuf50-09.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=5882, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=5282, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=2728, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=3738, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=5882, last_improvement=0, pop_size=450, max_weight=1612),
#   Result(formula_name='wuf50-010.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=5363, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=6761, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=2928, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=7334, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=215, weight=10275, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=216, weight=6760, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=5676, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=216, weight=6761, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=215, weight=7604, last_improvement=0, pop_size=450, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=6760, last_improvement=0, pop_size=450, max_weight=3031)],
#  '218-300': [Result(formula_name='wuf50-01.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=215, weight=24547, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=11548, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=15226, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=215, weight=25528, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=4190, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=16836, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-01.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=24789, last_improvement=0, pop_size=300, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=16517, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=17474, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=17796, last_improvement=0, pop_size=300, max_weight=1469),
#   Result(formula_name='wuf50-03.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=6825, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=4906, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-04.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=5754, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-03.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=5232, last_improvement=0, pop_size=300, max_weight=5305),
#   Result(formula_name='wuf50-04.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=7884, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=1488, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=11085, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=216, weight=11084, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=7884, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=300, max_weight=1488),
#   Result(formula_name='wuf50-05.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=12204, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=10634, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-06.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-05.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=8943, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=300, max_weight=11315),
#   Result(formula_name='wuf50-06.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=15780, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=15780, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=15779, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=15782, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=15289, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=300, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=9281, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=8569, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=8569, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=8845, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=216, weight=18262, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=11685, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=9480, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=8845, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=8845, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=14341, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-07.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=8845, last_improvement=0, pop_size=300, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=215, weight=16458, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=215, weight=14336, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=14338, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=215, weight=15396, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=11156, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=215, weight=16458, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=215, weight=14339, last_improvement=0, pop_size=300, max_weight=555),
#   Result(formula_name='wuf50-09.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=3094, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=4764, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=5517, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=5882, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=3928, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=3928, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=5001, last_improvement=0, pop_size=300, max_weight=1612),
#   Result(formula_name='wuf50-010.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=3031, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=6201, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=7353, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=5681, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=216, weight=9122, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=3031, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=2963, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=216, weight=8241, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=216, weight=9074, last_improvement=0, pop_size=300, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=8653, last_improvement=0, pop_size=300, max_weight=3031)],
#  '218-200': [Result(formula_name='wuf50-01.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=24547, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=26261, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=13754, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=18906, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=24790, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=11302, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=21848, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=24787, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=216, weight=18903, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=16193, last_improvement=0, pop_size=200, max_weight=1469),
#   Result(formula_name='wuf50-01.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=17188, last_improvement=0, pop_size=200, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=16517, last_improvement=0, pop_size=200, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=17796, last_improvement=0, pop_size=200, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=16517, last_improvement=0, pop_size=200, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=17474, last_improvement=0, pop_size=200, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=200, max_weight=1469),
# ...
#   Result(formula_name='wuf50-09.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=100, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=215, weight=4660, last_improvement=0, pop_size=100, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=3738, last_improvement=0, pop_size=100, max_weight=1612),
#   Result(formula_name='wuf50-010.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=8786, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=215, weight=8630, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=216, weight=11110, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=8786, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=8786, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=5363, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=11110, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=213, weight=10964, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=216, weight=9717, last_improvement=0, pop_size=100, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=216, weight=7613, last_improvement=0, pop_size=100, max_weight=3031)],
#  '218-50': [Result(formula_name='wuf50-01.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=24055, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=24790, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=21845, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=21845, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=216, weight=18906, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=215, weight=22092, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=17925, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=216, weight=16454, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=216, weight=16453, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-01.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=215, weight=19886, last_improvement=0, pop_size=50, max_weight=4190),
#   Result(formula_name='wuf50-02.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=11391, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=14589, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=216, weight=11075, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=17796, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=11713, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=15875, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=3708, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=7233, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-02.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=16837, last_improvement=0, pop_size=50, max_weight=1469),
#   Result(formula_name='wuf50-03.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=217, weight=9479, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=5232, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=9351, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=217, weight=8309, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=9479, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=8693, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-03.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=5305, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-04.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=14286, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=214, weight=15352, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-03.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=5287, last_improvement=0, pop_size=50, max_weight=5305),
#   Result(formula_name='wuf50-04.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=7884, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=12819, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=215, weight=13216, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=12151, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=13217, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=12819, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-04.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=11087, last_improvement=0, pop_size=50, max_weight=1488),
#   Result(formula_name='wuf50-05.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=218, weight=8943, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=216, weight=14405, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=218, weight=8775, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=9489, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=218, weight=8066, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=216, weight=14089, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=218, weight=9532, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=218, weight=10734, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-05.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=218, weight=10634, last_improvement=0, pop_size=50, max_weight=11315),
#   Result(formula_name='wuf50-06.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=16766, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=14305, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=17751, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=216, weight=17751, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=6916, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=214, weight=15773, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=16273, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=13317, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-06.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=215, weight=13310, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=12063, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=215, weight=10789, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-06.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=15780, last_improvement=0, pop_size=50, max_weight=1012),
#   Result(formula_name='wuf50-07.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=216, weight=18262, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=215, weight=12168, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=6609, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=218, weight=9570, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=218, weight=8845, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=215, weight=14572, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=217, weight=8206, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-07.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=214, weight=15730, last_improvement=0, pop_size=50, max_weight=9570),
#   Result(formula_name='wuf50-08.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=215, weight=13279, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=13810, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=214, weight=15401, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=11688, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=216, weight=11162, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=216, weight=14869, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=215, weight=12221, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=215, weight=16463, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=214, weight=19637, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-08.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=215, weight=12222, last_improvement=0, pop_size=50, max_weight=555),
#   Result(formula_name='wuf50-09.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=217, weight=4763, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=214, weight=4424, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=217, weight=5882, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=5, clause_cnt=218, sat_clause_cnt=217, weight=5882, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=4, clause_cnt=218, sat_clause_cnt=217, weight=4764, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=6, clause_cnt=218, sat_clause_cnt=217, weight=3738, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=3, clause_cnt=218, sat_clause_cnt=216, weight=5331, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=7, clause_cnt=218, sat_clause_cnt=215, weight=6056, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=8, clause_cnt=218, sat_clause_cnt=217, weight=4678, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-09.mwcnf', run_no=9, clause_cnt=218, sat_clause_cnt=217, weight=4739, last_improvement=0, pop_size=50, max_weight=1612),
#   Result(formula_name='wuf50-010.mwcnf', run_no=0, clause_cnt=218, sat_clause_cnt=216, weight=5724, last_improvement=0, pop_size=50, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=2, clause_cnt=218, sat_clause_cnt=215, weight=7858, last_improvement=0, pop_size=50, max_weight=3031),
#   Result(formula_name='wuf50-010.mwcnf', run_no=1, clause_cnt=218, sat_clause_cnt=216, weight=11110, last_improvement=0, pop_size=50, max_weight=3031)]}

# %%
from copy import deepcopy
from numpy import mean

filtered_stats = deepcopy(stats)
for key, result_list in stats.items():
    if result_list[0].clause_cnt == 430:
        filtered_stats.pop(key)

averages = []
for key, result_list in filtered_stats.items():
    averages.append(
        (mean([result.get_int() for result in result_list]),
         mean([result.get_penalized_last_improvement() for result in result_list]),
         mean([result.last_improvement for result in result_list]),
         key)
    )

averages.sort(reverse=True)
print("\n".join([str(avg) for avg in averages]))
print("-------")
averages.sort(key=lambda x: x[1])
print("\n".join([str(avg) for avg in averages]))

# for succ_avg, ppz_avg, key in averages[:10]:
#     results = stats[key]
#     for result in results:
#         file_name = f"out/{result.formula_name}-{result.run_no}-{result.tour_size}-{result.cross}-{float(result.mut)}"
#         debug_stream = StringIO()
#         with open(file_name, "rt") as f:
#             debug_stream.writelines(f.readlines())

#         print_plot(debug_stream=debug_stream,
#                    title=file_name,
#                    out_file=Path(file_name + ".png"))
# Out:
# (0.2850910371949254, 0.0, 0.0, '218-600')
# (0.251915216831247, 0.0, 0.0, '218-300')
# (0.21855376707026283, 0.0, 0.0, '218-450')
# (0.17052566874486966, 0.0, 0.0, '218-150')
# (0.14617604154648894, 0.0, 0.0, '218-50')
# (0.14612710098280046, 0.0, 0.0, '218-200')
# (0.12167052658839049, 0.0, 0.0, '218-100')
# -------
# (0.2850910371949254, 0.0, 0.0, '218-600')
# (0.251915216831247, 0.0, 0.0, '218-300')
# (0.21855376707026283, 0.0, 0.0, '218-450')
# (0.17052566874486966, 0.0, 0.0, '218-150')
# (0.14617604154648894, 0.0, 0.0, '218-50')
# (0.14612710098280046, 0.0, 0.0, '218-200')
# (0.12167052658839049, 0.0, 0.0, '218-100')

# %%
selected_hyperparameters = {
    "population_size": 100,
    "number_of_generations": 500,
    "selection": TournamentSelection(1.5),
    "crossover_probability": 0.9,
    "mutation_rate": 0.01,
    "elitism": 1
}

instances = [
    "wuf20-91/wuf20-91-Q/wuf20-01.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-02.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-03.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-04.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-05.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-06.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-07.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-08.mwcnf",
    "wuf20-91/wuf20-91-Q/wuf20-09.mwcnf",
]

solved = 0
for instance in instances:
    for i in range(10):
        debug_stream = StringIO()
        formula_path = Path(instance)
        formula = parse_mwcnf(formula_path)
        solution, actual_generation_cnt, _ = genetic_algorithm(MwcnfGenerator(formula),
                                                            debug_stream=debug_stream,
                                                            **selected_hyperparameters)
        print_plot(debug_stream,
                   title=f"{formula_path.name}")

        clause_cnt = formula.clause_cnt
        sat_clause_cnt = -satisfied_clause_count(formula, solution.config)
        weight = -weights(formula, solution.config)
        print(f"{clause_cnt=}, {sat_clause_cnt=}, {weight=}")
        solved += clause_cnt == sat_clause_cnt

solved
